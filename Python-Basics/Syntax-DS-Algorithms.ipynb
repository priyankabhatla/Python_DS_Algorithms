# %% [markdown]
# ## __Syntax__:
#
#    ### Variables :
#
#    __Names__:
#    -  Must start with letters or underscores.
#    - Contain Letters/ Numbers/underscore.
#    - Case sensitive
#
#
#  __Input Function__:
#    - Returns a string
#    - #1
#
# - Indentation is necessary in python.

# %%
name="Micheal"
print(name)
print(len(name))
#1
print("\n")

nam=input ('Name? ')
print("hello",nam) 
print("Hello "+nam+".It was fun seeing you")
print("\n")


#String as array
a = "Hello, World!"
print(a[1])
print("\n")

#String Slicing
b = "Hello, World!"
print(b[2:5])
print("\n")

#Negetive Indexing
b = "Hello, World!"
print(b[-5:-2])
print("\n")

#Split
a = "Hello, World!"
print(a.split(","))
print("\n")

#String Formatting
age1=36
age2=78
text="Micheal is {} years old.His grandpa is {} years old."
print(text.format(age1,age2))
print("\n")

quantity = 3
itemno = 567
price = 49.95
myorder = "I want {1} pieces of item {2} for {0} dollars."
print(myorder.format(price,quantity, itemno))
print("\n")

#String Conversion:
sval='123'
Ival=int(sval)
print(Ival+1)
Ans: 124
# Out:
# Micheal
# 7
#
#
# Name? Larry
# hello Larry
# Hello Larry.It was fun seeing you
#
#
# e
#
#
# llo
#
#
# orl
#
#
# ['Hello', ' World!']
#
#
# Micheal is 36 years old.His grandpa is 78 years old.
#
#
# I want 3 pieces of item 567 for 49.95 dollars.
#
#
# 124

# %% [markdown]
# ## Python Conditions and If statements

# %%
# If
a = 33
b = 200
if b > a:
  print("b is greater than a \n")

#Elif
a = 33
b = 33
if b > a:
  print("b is greater than a \n")
elif a == b:
  print("a and b are equal \n")

#Else
a = 200
b = 33
if b > a:
  print("b is greater than a \n")
elif a == b:
  print("a and b are equal \n")
else:
  print("a is greater than b \n")

#If Else
a = 200
b = 33
if b > a:
  print("b is greater than a \n")
else:
  print("b is not greater than a \n")
    
#Ternary Operator
a = 2
b = 330
print("A") if a > b else print("B \n")


#And
a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both conditions are True \n")

#Or
a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least one of the conditions is True \n")

#Nested If
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")
# Out:
# b is greater than a
#
# a and b are equal
#
# a is greater than b
#
# b is not greater than a
#
# B
#
# Both conditions are True
#
# At least one of the conditions is True
#
# Above ten,
# and also above 20!

# %% [markdown]
# ## Loops
#
# __Break__:The break statement allows us to stop the loop even if the while condition is true. <br>
# __Continue__:The continue statement allows us to stop the current iteration, and continue with the next.

# %%
# While Loop:
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1

print("\n")

i = 0
while i < 6:
  i += 1
  if i == 3:
    print("overruled")
    continue
  print(i)

print("\n")

# For loop:

fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)

print("\n")

#Looping through a string.
for x in "banana":
  print(x,end=" ")

print("\n")

fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x,end=" ")
  if x == "banana":
    break
print("\n")

# Range function
for x in range(6):
  print(x, end=" ")

print("\n")

for x in range(2, 6):
  print(x,end=" ")

print("\n")

for x in range(2, 30, 3):
  print(x,end=" ")

print("\n")

adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

for x in adj:
  for y in fruits:
    print(x, y)
# Out:
# 1
# 2
# 3
#
#
# 1
# 2
# overruled
# 4
# 5
# 6
#
#
# apple
# banana
# cherry
#
#
# b a n a n a
#
# apple banana
#
# 0 1 2 3 4 5
#
# 2 3 4 5
#
# 2 5 8 11 14 17 20 23 26 29
#
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %% [markdown]
# ## Functions

# %%
# Calling a Function

def my_function():
  print("Hello from a function")

my_function()
print("\n")

# Passing Arguments
def my_function(fname):
  print(fname + " Refsnes")

my_function("Emil")
my_function("Tobias")
my_function("Linus")
print("\n")

# Arbitary Arguments
def kidz(*k):
    print("The youngest one is "+ k[0])

kidz('anna','maria','bina')
print("\n")

# Keyword Arguments
def my_function(child3, child2, child1):
  print("The youngest child is " + child1)

my_function(child1 = "Emil", child2 = "Tobias", child3 = "Linus")
print("\n")

# Default Parameter Value
def my_function(country = "Norway"):
  print("I am from " + country)

my_function("Sweden")
my_function("India")
my_function()
my_function("Brazil")
print("\n")

# Passing a list as an argument
def my_function(food):
  for x in food:
    print(x)

fruits = ["apple", "banana", "cherry"]

my_function(fruits)
print("\n")

def my_function(x):
  return 5 * x

print(my_function(3))
print(my_function(5))
print(my_function(9))
print("\n")

#Recursion
def tri_recursion(k):
  if(k > 0):
    result = k + tri_recursion(k - 1)
    print(result)
  else:
    result = 0
  return result

print("\nRecursion")
tri_recursion(6)
# Out:
# Hello from a function
#
#
# Emil Refsnes
# Tobias Refsnes
# Linus Refsnes
#
#
# The youngest one is anna
#
#
# The youngest child is Emil
#
#
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil
#
#
# apple
# banana
# cherry
#
#
# 15
# 25
# 45
#
#
#
# Recursion
# 1
# 3
# 6
# 10
# 15
# 21
# 21

# %% [markdown]
# ## Lambda Functions
# - A lambda function is a small anonymous function.
# - A lambda function can take any number of arguments, but can only have one expression.
# - lambda arguments : expression

# %%
x = lambda a : a + 10
print(x(5))
print("\n")

x = lambda a, b : a * b
print(x(5, 6))

print("\n")
def myfunc(n):
  return lambda a : a * n

mydoubler = myfunc(2)

print(mydoubler(11))
# Out:
# 15
#
#
# 30
#
#
# 22

# %% [markdown]
# ## Classes
#
# ### __Init__ Function:
# - All classes have a function called __init__(), which is always executed when the class is being initiated.
# - Use the __init__() function to assign values to object properties.
# - The __init__() function is called automatically every time the class is being used to create a new object.
# - The self parameter is a reference to the current instance of the class, and is used to access variables that belong to the class.
# - It does not have to be named self , you can call it whatever you like, but it has to be the first parameter of any function in the class

# %%
# Class and Object creation
class first:
    x=5
    
obj=first()
print(first.x)
print("\n")

# Init Function

class teacher:
    def __init__(self,name,age,subject):
        self.name=name
        self.age=age
        self.subject=subject
        
    def details(self):
        print("My name is "+self.name+". I am "+str(self.age)+" years old. I teach "+self.subject)

t1=teacher("Mary",24,"GK")
t2=teacher("Clara",26,"Maths")
print(t1.name)
print(t1.age)
print(t1.subject)

#calling object functions

t1.details()
t2.details()

# Changing object values
t1.subject="English"
t2.age=29

print("\n")

t1.details()
t2.details()
# Out:
# 5
#
#
# Mary
# 24
# GK
# My name is Mary. I am 24 years old. I teach GK
# My name is Clara. I am 26 years old. I teach Maths
#
#
# My name is Mary. I am 24 years old. I teach English
# My name is Clara. I am 29 years old. I teach Maths

# %% [markdown]
# ## Inheritance
# - Super() function will make the child class inherit all the methods and properties from its parent

# %%
class person:
    def __init__(self,fname,lname,loc):
        self.firstname=fname
        self.lastname=lname
        self.location=loc
    def printname(self):
        print("My name is "+self.firstname+" "+self.lastname)
        
    def printloc(self):
        print(self.fname+" belongs from "+self.location)
        
class employee(person):
    #pass
    def __init__(self, fname, lname,loc):
        person.__init__(self, fname, lname,loc)
        print("I just inherited from the other class")
    #super method
    def printloc(self):
        super().printloc(se)
        

x=person("john","Doe","Arizona")
x.printname()
y=employee("Rihana","Sanders","Bahamas")
y.printname()
# Out:
# My name is john Doe
# I just inherited from the other class
# My name is Rihana Sanders

# %% [markdown]
# ## Exception Handling
# - The **try** block lets you test a block of code for errors.
#
# - The **except** block lets you handle the error.
#
# - The **finally** block lets you execute code, regardless of the result of the try- and except blocks.

# %%
try:
  print(r)
except:
  print("An exception occurred \n")


try:
  print(r)
except NameError:
  print("Variable x is not defined \n")
except:
  print("Something else went wrong \n")

try:
  print(r)
except:
  print("Something went wrong ")
finally:
  print("The 'try except' is finished \n")

try:
  f = open("demofile.txt")
  f.write("Lorum Ipsum")
except:
  print("Something went wrong when writing to the file")
finally:
  print("File closed")
# Out:
# An exception occurred
#
# Variable x is not defined
#
# Something went wrong
# The 'try except' is finished
#
# Something went wrong when writing to the file
# File closed
